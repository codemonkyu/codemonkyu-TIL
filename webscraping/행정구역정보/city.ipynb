# %% [markdown]
# #### data_dtaw_korea.csv 파일을 판다스로 읽어오자.

# %%
import pandas as pd

data = pd.read_csv('data_draw_korea.csv')
#print(data)

data.sample(3)
# Out:
#      Unnamed: 0     인구수 shortName   x   y      면적   광역시도 행정구역
# 17           17   39668        횡성  10   5  997.82    강원도  횡성군
# 115         115  292375      부산북구   9  16   38.30  부산광역시   북구
# 106         106  321618      대전유성   4  13  177.16  대전광역시  유성구

# %%
data.describe()
# Out:
#        Unnamed: 0           인구수           x           y           면적
# count  229.000000  2.290000e+02  229.000000  229.000000   229.000000
# mean   114.000000  2.110898e+05    6.117904   11.262009   435.419795
# std     66.250786  2.074378e+05    3.320469    6.040898   381.612549
# min      0.000000  8.392000e+03    0.000000    0.000000     2.800000
# 25%     57.000000  4.955900e+04    3.000000    6.000000    54.000000
# 50%    114.000000  1.401590e+05    6.000000   11.000000   436.400000
# 75%    171.000000  3.216180e+05    9.000000   16.000000   692.800000
# max    228.000000  1.125461e+06   13.000000   25.000000  1817.940000

# %%
data['광역시도'].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도'], dtype=object)

# %%
data.loc[data['광역시도']=='서울특별시'].sort_values(by='인구수',ascending=False).reset_index(drop=True)
# Out:
#     Unnamed: 0     인구수 shortName  x  y     면적   광역시도  행정구역
# 0          141  615487      서울송파  8  6  33.90  서울특별시   송파구
# 1          127  554709      서울강서  4  4  41.40  서울특별시   강서구
# 2          132  547202      서울노원  6  1  35.44  서울특별시   노원구
# 3          124  526157      서울강남  6  7  39.50  서울특별시   강남구
# 4          128  484478      서울관악  5  6  29.60  서울특별시   관악구
# 5          145  464236      서울은평  4  3  29.70  서울특별시   은평구
# 6          142  453634      서울양천  4  5  17.40  서울특별시   양천구
# 7          140  434061      서울성북  6  2  24.57  서울특별시   성북구
# 8          125  432028      서울강동  8  5  24.60  서울특별시   강동구
# 9          138  407416      서울서초  6  6  47.04  서울특별시   서초구
# 10         130  401233      서울구로  4  7  20.11  서울특별시   구로구
# 11         148  391655      서울중랑  8  4  18.50  서울특별시   중랑구
# 12         135  383917      서울동작  5  5  16.36  서울특별시   동작구
# 13         136  364232      서울마포  5  4  23.87  서울특별시   마포구
# 14         143  351837     서울영등포  4  6  24.56  서울특별시  영등포구
# 15         129  342909      서울광진  7  6  17.05  서울특별시   광진구
# 16         134  342429     서울동대문  7  4  14.20  서울특별시  동대문구
# 17         133  331682      서울도봉  5  1  20.80  서울특별시   도봉구
# 18         126  310292      서울강북  5  2  23.60  서울특별시   강북구
# 19         137  288543     서울서대문  5  3  17.60  서울특별시  서대문구
# 20         139  279939      서울성동  7  5  16.85  서울특별시   성동구
# 21         131  222566      서울금천  5  7  13.01  서울특별시   금천구
# 22         144  208603      서울용산  6  5  21.87  서울특별시   용산구
# 23         146  140595      서울종로  6  3  23.90  서울특별시   종로구
# 24         147  114967      서울중구  6  4   9.96  서울특별시    중구

# %%
data.loc[data['광역시도']=='경상북도',['행정구역','인구수','면적']].sort_values(by='인구수',ascending=False).reset_index(drop=True)
# Out:
#    행정구역     인구수       면적
# 0   포항시  488395  1127.00
# 1   구미시  396685   616.10
# 2   경산시  251220   411.58
# 3   경주시  242618  1323.85
# 4   안동시  157317  1519.00
# 5   김천시  127941  1009.56
# 6   칠곡군  112446   451.00
# 7   영주시  101612   668.45
# 8   상주시   93305  1254.82
# 9   영천시   91214   919.76
# 10  문경시   67919   912.00
# 11  의성군   48776  1175.89
# 12  울진군   46748   989.06
# 13  예천군   40779   660.70
# 14  청도군   38571   696.52
# 15  성주군   38277   616.28
# 16  영덕군   34864   741.05
# 17  고령군   31189   383.70
# 18  봉화군   30287  1201.00
# 19  청송군   23804   842.45
# 20  군위군   20596   614.15
# 21  영양군   16009   815.11
# 22  울릉군    8392    72.82

# %%
data.iloc[20:25,1:4]
# Out:
#        인구수 shortName  x
# 20   63227        과천  7
# 21  327111        광명  3
# 22  290210        광주  8
# 23  175676        구리  9
# 24  273302        군포  5

# %%
pop_mean_value = data['인구수'].mean()
print([pop_mean_value])
# Out:
# [211089.77729257641]

# %%
pop_mean_under = data.loc[data['인구수'] <= pop_mean_value, ['인구수','행정구역','면적','광역시도']]

pop_mean_under
# Out:
#         인구수 행정구역       면적  광역시도
# 0    202520  강릉시  1040.07   강원도
# 1     25589  고성군   664.19   강원도
# 2     86747  동해시   180.01   강원도
# 3     63986  삼척시  1185.80   강원도
# 4     76733  속초시   105.25   강원도
# ..      ...  ...      ...   ...
# 223   86441  음성군   521.05  충청북도
# 224  127462  제천시   882.47  충청북도
# 225   34480  증평군    81.84  충청북도
# 226   62809  진천군   406.08  충청북도
# 228  198077  충주시   983.70  충청북도
#
# [141 rows x 4 columns]

# %%
pop_mean_under.to_excel('전국인구평균미만지역.xls')
# Out:
# C:\Users\JUNKYU~1\AppData\Local\Temp/ipykernel_26156/3524708326.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   pop_mean_under.to_excel('전국인구평균미만지역.xls')

# %%
data.rename(columns={'Unnamed: 0':'num'})
# Out:
#      num     인구수 shortName   x   y       면적  광역시도 행정구역
# 0      0  202520        강릉  11   4  1040.07   강원도  강릉시
# 1      1   25589    고성(강원)   9   0   664.19   강원도  고성군
# 2      2   86747        동해  11   5   180.01   강원도  동해시
# 3      3   63986        삼척  11   8  1185.80   강원도  삼척시
# 4      4   76733        속초   9   1   105.25   강원도  속초시
# ..   ...     ...       ...  ..  ..      ...   ...  ...
# 224  224  127462        제천   8  10   882.47  충청북도  제천시
# 225  225   34480        증평   6  11    81.84  충청북도  증평군
# 226  226   62809        진천   5  11   406.08  충청북도  진천군
# 227  227  790216        청주   6  12   932.51  충청북도  청주시
# 228  228  198077        충주   6  10   983.70  충청북도  충주시
#
# [229 rows x 8 columns]

# %%
data.loc[data['광역시도'] == '경기도', ['행정구역','인구수']]\
    .sort_values(by='인구수',ascending=False)\
    .reset_index(drop=True)
# Out:
#     행정구역      인구수
# 0    수원시  1125461
# 1    고양시   955384
# 2    용인시   915005
# 3    성남시   911628
# 4    부천시   805473
# 5    안산시   668089
# 6   남양주시   610300
# 7    안양시   566558
# 8    화성시   555129
# 9    평택시   423763
# 10  의정부시   408220
# 11   파주시   385528
# 12   시흥시   381412
# 13   광명시   327111
# 14   김포시   326523
# 15   광주시   290210
# 16   군포시   273302
# 17   오산시   200793
# 18   양주시   191266
# 19   이천시   190537
# 20   구리시   175676
# 21   안성시   173061
# 22   하남시   150061
# 23   의왕시   149080
# 24   포천시   140159
# 25   여주시   100669
# 26   양평군    95614
# 27  동두천시    90398
# 28   과천시    63227
# 29   가평군    53497
# 30   연천군    41076

# %%
pop_max_value = data.loc[data['광역시도'] == '경기도','인구수'].max()

print(pop_max_value)
# Out:
# 1125461

# %% [markdown]
# ## 광역시도를 아규먼트로 받아서 광역시도중 가장 인구가 많은 행정구역을 반환하는 함수 정의하기

# %%
def find_city_max(city):
    pop_max_value = data.loc[data['광역시도'] == city,'인구수'].max()
    return data.loc[(data['인구수'] == pop_max_value) & (data['광역시도'] == city), ['광역시도','행정구역','인구수']]
    
find_city_max('경기도')
# Out:
#    광역시도 행정구역      인구수
# 30  경기도  수원시  1125461

# %%
for city in data['광역시도'].unique():
    
    print(find_city_max(city))
    print(type(find_city_max(city)))
# Out:
#   광역시도 행정구역     인구수
# 8  강원도  원주시  313851
# <class 'pandas.core.frame.DataFrame'>
#    광역시도 행정구역      인구수
# 30  경기도  수원시  1125461
# <class 'pandas.core.frame.DataFrame'>
#     광역시도 행정구역      인구수
# 61  경상남도  창원시  1010040
# <class 'pandas.core.frame.DataFrame'>
#     광역시도 행정구역     인구수
# 89  경상북도  포항시  488395
# <class 'pandas.core.frame.DataFrame'>
#      광역시도 행정구역     인구수
# 93  광주광역시   북구  439683
# <class 'pandas.core.frame.DataFrame'>
#      광역시도 행정구역     인구수
# 96  대구광역시  달서구  584517
# <class 'pandas.core.frame.DataFrame'>
#       광역시도 행정구역     인구수
# 105  대전광역시   서구  475094
# <class 'pandas.core.frame.DataFrame'>
#       광역시도  행정구역     인구수
# 123  부산광역시  해운대구  397134
# <class 'pandas.core.frame.DataFrame'>
#       광역시도 행정구역     인구수
# 141  서울특별시  송파구  615487
# <class 'pandas.core.frame.DataFrame'>
#         광역시도 행정구역     인구수
# 149  세종특별자치시  세종시  191233
# <class 'pandas.core.frame.DataFrame'>
#       광역시도 행정구역     인구수
# 150  울산광역시   남구  327270
# <class 'pandas.core.frame.DataFrame'>
#       광역시도 행정구역     인구수
# 160  인천광역시  부평구  527153
# <class 'pandas.core.frame.DataFrame'>
#      광역시도 행정구역     인구수
# 177  전라남도  여수시  263166
# <class 'pandas.core.frame.DataFrame'>
#      광역시도 행정구역     인구수
# 198  전라북도  전주시  630708
# <class 'pandas.core.frame.DataFrame'>
#         광역시도 행정구역     인구수
# 202  제주특별자치도  제주시  430504
# <class 'pandas.core.frame.DataFrame'>
#      광역시도 행정구역     인구수
# 214  충청남도  천안시  584912
# <class 'pandas.core.frame.DataFrame'>
#      광역시도 행정구역     인구수
# 227  충청북도  청주시  790216
# <class 'pandas.core.frame.DataFrame'>

# %%
pop_max_city_df = pd.DataFrame(columns=['광역시도','행정구역','인구수'])

for city in data['광역시도'].unique():
    pop_max_city_df = pop_max_city_df.append(find_city_max(city))
    
print(pop_max_city_df.reset_index(drop=True))
# Out:
#        광역시도  행정구역      인구수
# 0       강원도   원주시   313851
# 1       경기도   수원시  1125461
# 2      경상남도   창원시  1010040
# 3      경상북도   포항시   488395
# 4     광주광역시    북구   439683
# 5     대구광역시   달서구   584517
# 6     대전광역시    서구   475094
# 7     부산광역시  해운대구   397134
# 8     서울특별시   송파구   615487
# 9   세종특별자치시   세종시   191233
# 10    울산광역시    남구   327270
# 11    인천광역시   부평구   527153
# 12     전라남도   여수시   263166
# 13     전라북도   전주시   630708
# 14  제주특별자치도   제주시   430504
# 15     충청남도   천안시   584912
# 16     충청북도   청주시   790216

# %%
def find_city_two_max(city):
    pop_max_land = data.loc[data['광역시도'] == city,'면적'].max()
    pop_max_value = data.loc[data['광역시도'] == city,'인구수'].max()
    return (data.loc[(data['광역시도'] == city ) & (data['면적'] == pop_max_land),['광역시도','행정구역','면적']] ,
            data.loc[(data['광역시도'] == city ) & (data['인구수'] == pop_max_value),['광역시도','행정구역','인구수']])


pop_land_city_max_df = pd.DataFrame(columns=['광역시도','행정구역','인구수','면적'])
for city in data['광역시도'].unique():
    pop_land_city_max_df = pop_land_city_max_df.append(find_city_two_max(city))


print(pop_land_city_max_df.reset_index(drop=True).fillna(0))
# Out:
#        광역시도  행정구역        인구수       면적
# 0       강원도   홍천군        0.0  1817.94
# 1       강원도   원주시   313851.0     0.00
# 2       경기도   양평군        0.0   877.08
# 3       경기도   수원시  1125461.0     0.00
# 4      경상남도   합천군        0.0   983.42
# 5      경상남도   창원시  1010040.0     0.00
# 6      경상북도   안동시        0.0  1519.00
# 7      경상북도   포항시   488395.0     0.00
# 8     광주광역시   광산구        0.0   222.88
# 9     광주광역시    북구   439683.0     0.00
# 10    대구광역시   달성군        0.0   427.03
# 11    대구광역시   달서구   584517.0     0.00
# 12    대전광역시   유성구        0.0   177.16
# 13    대전광역시    서구   475094.0     0.00
# 14    부산광역시   기장군        0.0   217.90
# 15    부산광역시  해운대구   397134.0     0.00
# 16    서울특별시   서초구        0.0    47.04
# 17    서울특별시   송파구   615487.0     0.00
# 18  세종특별자치시   세종시        0.0   465.23
# 19  세종특별자치시   세종시   191233.0     0.00
# 20    울산광역시   울주군        0.0   754.93
# 21    울산광역시    남구   327270.0     0.00
# 22    인천광역시   강화군        0.0   411.20
# 23    인천광역시   부평구   527153.0     0.00
# 24     전라남도   순천시        0.0   907.35
# 25     전라남도   여수시   263166.0     0.00
# 26     전라북도   완주군        0.0   821.00
# 27     전라북도   전주시   630708.0     0.00
# 28  제주특별자치도   제주시        0.0   977.80
# 29  제주특별자치도   제주시   430504.0     0.00
# 30     충청남도   공주시        0.0   940.71
# 31     충청남도   천안시   584912.0     0.00
# 32     충청북도   충주시        0.0   983.70
# 33     충청북도   청주시   790216.0     0.00

# %%
import numpy as np
import pandas as pd

def max_function(city):
    max_temp = data.loc[data['광역시도'] == city]
    max_people = max_temp['인구수'].max()
    max_land = max_temp['면적'].max()
    
    result = max_temp.loc[(max_temp['인구수'] == max_people) | (max_temp['면적'] == max_land),['광역시도','행정구역','인구수','면적']]
    return result

pop_max_city = pd.DataFrame(columns=['광역시도','행정구역','인구수','면적'])
for i in data['광역시도'].unique():
    pop_max_city = pop_max_city.append(max_function(i))
    
pop_max_city.reset_index(drop=True)
# Out:
#        광역시도  행정구역      인구수       면적
# 0       강원도   원주시   313851   867.30
# 1       강원도   홍천군    62957  1817.94
# 2       경기도   수원시  1125461   121.09
# 3       경기도   양평군    95614   877.08
# 4      경상남도   창원시  1010040   734.87
# 5      경상남도   합천군    42515   983.42
# 6      경상북도   안동시   157317  1519.00
# 7      경상북도   포항시   488395  1127.00
# 8     광주광역시   광산구   389386   222.88
# 9     광주광역시    북구   439683   121.74
# 10    대구광역시   달서구   584517    62.30
# 11    대구광역시   달성군   178203   427.03
# 12    대전광역시    서구   475094    95.25
# 13    대전광역시   유성구   321618   177.16
# 14    부산광역시   기장군   142223   217.90
# 15    부산광역시  해운대구   397134    51.44
# 16    서울특별시   서초구   407416    47.04
# 17    서울특별시   송파구   615487    33.90
# 18  세종특별자치시   세종시   191233   465.23
# 19    울산광역시    남구   327270    72.11
# 20    울산광역시   울주군   203232   754.93
# 21    인천광역시   강화군    58296   411.20
# 22    인천광역시   부평구   527153    32.00
# 23     전라남도   순천시   254751   907.35
# 24     전라남도   여수시   263166   501.30
# 25     전라북도   완주군    87465   821.00
# 26     전라북도   전주시   630708   206.45
# 27  제주특별자치도   제주시   430504   977.80
# 28     충청남도   공주시   102371   940.71
# 29     충청남도   천안시   584912   636.50
# 30     충청북도   청주시   790216   932.51
# 31     충청북도   충주시   198077   983.70

# %%
print(len(pop_max_city))
pop_max_city.index
# Out:
# 32
# Int64Index([  8,  15,  30,  36,  61,  66,  77,  89,  90,  93,  96,  97, 105,
#             106, 110, 123, 138, 141, 149, 150, 153, 155, 160, 175, 177, 194,
#             198, 202, 204, 214, 227, 228],
#            dtype='int64')

# %%
pop_max_city.index = np.arange(1, len(pop_max_city)+1)

# %%
pop_max_city
# Out:
#        광역시도  행정구역      인구수       면적
# 1       강원도   원주시   313851   867.30
# 2       강원도   홍천군    62957  1817.94
# 3       경기도   수원시  1125461   121.09
# 4       경기도   양평군    95614   877.08
# 5      경상남도   창원시  1010040   734.87
# 6      경상남도   합천군    42515   983.42
# 7      경상북도   안동시   157317  1519.00
# 8      경상북도   포항시   488395  1127.00
# 9     광주광역시   광산구   389386   222.88
# 10    광주광역시    북구   439683   121.74
# 11    대구광역시   달서구   584517    62.30
# 12    대구광역시   달성군   178203   427.03
# 13    대전광역시    서구   475094    95.25
# 14    대전광역시   유성구   321618   177.16
# 15    부산광역시   기장군   142223   217.90
# 16    부산광역시  해운대구   397134    51.44
# 17    서울특별시   서초구   407416    47.04
# 18    서울특별시   송파구   615487    33.90
# 19  세종특별자치시   세종시   191233   465.23
# 20    울산광역시    남구   327270    72.11
# 21    울산광역시   울주군   203232   754.93
# 22    인천광역시   강화군    58296   411.20
# 23    인천광역시   부평구   527153    32.00
# 24     전라남도   순천시   254751   907.35
# 25     전라남도   여수시   263166   501.30
# 26     전라북도   완주군    87465   821.00
# 27     전라북도   전주시   630708   206.45
# 28  제주특별자치도   제주시   430504   977.80
# 29     충청남도   공주시   102371   940.71
# 30     충청남도   천안시   584912   636.50
# 31     충청북도   청주시   790216   932.51
# 32     충청북도   충주시   198077   983.70

# %%
data['면적'].corr(data['인구수'])
# Out:
# -0.3460351605045771

# %%
seoul_df = data.loc[data['광역시도'] == '서울특별시']
seoul_df['면적'].corr(seoul_df['인구수'])
# Out:
# 0.664426818890978

# %%
data['인구수'].groupby(data['광역시도']).sum().sort_values(ascending=False)
# Out:
# 광역시도
# 경기도        11744210
# 서울특별시       9394807
# 부산광역시       3323591
# 경상남도        3144487
# 인천광역시       2766575
# 경상북도        2508964
# 대구광역시       2378450
# 충청남도        1946129
# 전라북도        1739048
# 전라남도        1700563
# 충청북도        1484720
# 대전광역시       1467677
# 광주광역시       1438209
# 강원도         1429438
# 울산광역시       1105585
# 제주특별자치도      575873
# 세종특별자치시      191233
# Name: 인구수, dtype: int64

# %%
data.groupby('광역시도').sum()
# Out:
#          Unnamed: 0       인구수    x    y         면적
# 광역시도
# 강원도             153   1429438  173   68  16874.810
# 경기도            1023  11744210  182  162  10179.743
# 경상남도           1035   3144487  123  313  10437.460
# 경상북도           1794   2508964  229  240  19021.850
# 광주광역시           460   1438209   12   99    501.280
# 대구광역시           788   2378450   74  111    885.690
# 대전광역시           525   1467677   23   66    539.640
# 부산광역시          1848   3323591  162  276    763.240
# 서울특별시          3400   9394807  142  111    605.390
# 세종특별자치시         149    191233    4   11    465.230
# 울산광역시           760   1105585   58   71    980.220
# 인천광역시          1595   2766575   13   61   1022.910
# 전라남도           3861   1700563   44  438  12008.390
# 전라북도           2709   1739048   46  219   7907.220
# 제주특별자치도         403    575873    8   49   1848.480
# 충청남도           3150   1946129   39  160   8272.270
# 충청북도           2453   1484720   69  124   7397.310

# %%
data.groupby('광역시도')['인구수'].sum()
# Out:
# 광역시도
# 강원도         1429438
# 경기도        11744210
# 경상남도        3144487
# 경상북도        2508964
# 광주광역시       1438209
# 대구광역시       2378450
# 대전광역시       1467677
# 부산광역시       3323591
# 서울특별시       9394807
# 세종특별자치시      191233
# 울산광역시       1105585
# 인천광역시       2766575
# 전라남도        1700563
# 전라북도        1739048
# 제주특별자치도      575873
# 충청남도        1946129
# 충청북도        1484720
# Name: 인구수, dtype: int64

# %%
group1 = data.groupby(['광역시도','행정구역'])['인구수'].sum()
group1.to_excel('광역시도별행정구역별인구수의합계2.xlsx')

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('광역시도별인구수의합계(최종).xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
group1.to_excel(writer, sheet_name='인구수')

# # Get the xlsxwriter workbook and worksheet objects.
workbook  = writer.book
worksheet = writer.sheets['인구수']

# # Set a currency number format for a column.
num_format = workbook.add_format({'num_format': '#,###'})
worksheet.set_column('C:C', None, num_format)

# # Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
group_agg_df = data.groupby('광역시도')['인구수'].agg(['max','mean','std']).fillna(0).sort_values(by='max',ascending=False)

group_agg_df.style.format('{0:0.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5d74_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >max</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >광역시도</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5d74_level0_row0" class="row_heading level0 row0" >경기도</th>
#       <td id="T_a5d74_row0_col0" class="data row0 col0" >1125461.00</td>
#       <td id="T_a5d74_row0_col1" class="data row0 col1" >378845.48</td>
#       <td id="T_a5d74_row0_col2" class="data row0 col2" >304548.40</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row1" class="row_heading level0 row1" >경상남도</th>
#       <td id="T_a5d74_row1_col0" class="data row1 col0" >1010040.00</td>
#       <td id="T_a5d74_row1_col1" class="data row1 col1" >174693.72</td>
#       <td id="T_a5d74_row1_col2" class="data row1 col2" >245796.47</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row2" class="row_heading level0 row2" >충청북도</th>
#       <td id="T_a5d74_row2_col0" class="data row2 col0" >790216.00</td>
#       <td id="T_a5d74_row2_col1" class="data row2 col1" >134974.55</td>
#       <td id="T_a5d74_row2_col2" class="data row2 col2" >223460.36</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row3" class="row_heading level0 row3" >전라북도</th>
#       <td id="T_a5d74_row3_col0" class="data row3 col0" >630708.00</td>
#       <td id="T_a5d74_row3_col1" class="data row3 col1" >124217.71</td>
#       <td id="T_a5d74_row3_col2" class="data row3 col2" >168327.13</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row4" class="row_heading level0 row4" >서울특별시</th>
#       <td id="T_a5d74_row4_col0" class="data row4 col0" >615487.00</td>
#       <td id="T_a5d74_row4_col1" class="data row4 col1" >375792.28</td>
#       <td id="T_a5d74_row4_col2" class="data row4 col2" >125231.25</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row5" class="row_heading level0 row5" >충청남도</th>
#       <td id="T_a5d74_row5_col0" class="data row5 col0" >584912.00</td>
#       <td id="T_a5d74_row5_col1" class="data row5 col1" >129741.93</td>
#       <td id="T_a5d74_row5_col2" class="data row5 col2" >141125.11</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row6" class="row_heading level0 row6" >대구광역시</th>
#       <td id="T_a5d74_row6_col0" class="data row6 col0" >584517.00</td>
#       <td id="T_a5d74_row6_col1" class="data row6 col1" >297306.25</td>
#       <td id="T_a5d74_row6_col2" class="data row6 col2" >174375.39</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row7" class="row_heading level0 row7" >인천광역시</th>
#       <td id="T_a5d74_row7_col0" class="data row7 col0" >527153.00</td>
#       <td id="T_a5d74_row7_col1" class="data row7 col1" >276657.50</td>
#       <td id="T_a5d74_row7_col2" class="data row7 col2" >199353.60</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row8" class="row_heading level0 row8" >경상북도</th>
#       <td id="T_a5d74_row8_col0" class="data row8 col0" >488395.00</td>
#       <td id="T_a5d74_row8_col1" class="data row8 col1" >109085.39</td>
#       <td id="T_a5d74_row8_col2" class="data row8 col2" >124954.74</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row9" class="row_heading level0 row9" >대전광역시</th>
#       <td id="T_a5d74_row9_col0" class="data row9 col0" >475094.00</td>
#       <td id="T_a5d74_row9_col1" class="data row9 col1" >293535.40</td>
#       <td id="T_a5d74_row9_col2" class="data row9 col2" >111853.57</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row10" class="row_heading level0 row10" >광주광역시</th>
#       <td id="T_a5d74_row10_col0" class="data row10 col0" >439683.00</td>
#       <td id="T_a5d74_row10_col1" class="data row10 col1" >287641.80</td>
#       <td id="T_a5d74_row10_col2" class="data row10 col2" >137076.68</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row11" class="row_heading level0 row11" >제주특별자치도</th>
#       <td id="T_a5d74_row11_col0" class="data row11 col0" >430504.00</td>
#       <td id="T_a5d74_row11_col1" class="data row11 col1" >287936.50</td>
#       <td id="T_a5d74_row11_col2" class="data row11 col2" >201620.89</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row12" class="row_heading level0 row12" >부산광역시</th>
#       <td id="T_a5d74_row12_col0" class="data row12 col0" >397134.00</td>
#       <td id="T_a5d74_row12_col1" class="data row12 col1" >207724.44</td>
#       <td id="T_a5d74_row12_col2" class="data row12 col2" >106246.04</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row13" class="row_heading level0 row13" >울산광역시</th>
#       <td id="T_a5d74_row13_col0" class="data row13 col0" >327270.00</td>
#       <td id="T_a5d74_row13_col1" class="data row13 col1" >221117.00</td>
#       <td id="T_a5d74_row13_col2" class="data row13 col2" >64163.29</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row14" class="row_heading level0 row14" >강원도</th>
#       <td id="T_a5d74_row14_col0" class="data row14 col0" >313851.00</td>
#       <td id="T_a5d74_row14_col1" class="data row14 col1" >79413.22</td>
#       <td id="T_a5d74_row14_col2" class="data row14 col2" >87316.38</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row15" class="row_heading level0 row15" >전라남도</th>
#       <td id="T_a5d74_row15_col0" class="data row15 col0" >263166.00</td>
#       <td id="T_a5d74_row15_col1" class="data row15 col1" >77298.32</td>
#       <td id="T_a5d74_row15_col2" class="data row15 col2" >74413.25</td>
#     </tr>
#     <tr>
#       <th id="T_a5d74_level0_row16" class="row_heading level0 row16" >세종특별자치시</th>
#       <td id="T_a5d74_row16_col0" class="data row16 col0" >191233.00</td>
#       <td id="T_a5d74_row16_col1" class="data row16 col1" >191233.00</td>
#       <td id="T_a5d74_row16_col2" class="data row16 col2" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
group_agg_df.reset_index(level='광역시도', inplace=False)
# Out:
#        광역시도      max           mean            std
# 0       경기도  1125461  378845.483871  304548.395142
# 1      경상남도  1010040  174693.722222  245796.465077
# 2      충청북도   790216  134974.545455  223460.356657
# 3      전라북도   630708  124217.714286  168327.134821
# 4     서울특별시   615487  375792.280000  125231.247975
# 5      충청남도   584912  129741.933333  141125.108080
# 6     대구광역시   584517  297306.250000  174375.394380
# 7     인천광역시   527153  276657.500000  199353.596491
# 8      경상북도   488395  109085.391304  124954.740885
# 9     대전광역시   475094  293535.400000  111853.571882
# 10    광주광역시   439683  287641.800000  137076.683206
# 11  제주특별자치도   430504  287936.500000  201620.892054
# 12    부산광역시   397134  207724.437500  106246.041384
# 13    울산광역시   327270  221117.000000   64163.286582
# 14      강원도   313851   79413.222222   87316.383238
# 15     전라남도   263166   77298.318182   74413.253230
# 16  세종특별자치시   191233  191233.000000       0.000000

# %%
group_agg_df.T
# Out:
# 광역시도           경기도          경상남도           충청북도           전라북도          서울특별시  \
# max   1.125461e+06  1.010040e+06  790216.000000  630708.000000  615487.000000
# mean  3.788455e+05  1.746937e+05  134974.545455  124217.714286  375792.280000
# std   3.045484e+05  2.457965e+05  223460.356657  168327.134821  125231.247975
#
# 광역시도           충청남도         대구광역시          인천광역시           경상북도  \
# max   584912.000000  584517.00000  527153.000000  488395.000000
# mean  129741.933333  297306.25000  276657.500000  109085.391304
# std   141125.108080  174375.39438  199353.596491  124954.740885
#
# 광역시도          대전광역시          광주광역시        제주특별자치도          부산광역시  \
# max   475094.000000  439683.000000  430504.000000  397134.000000
# mean  293535.400000  287641.800000  287936.500000  207724.437500
# std   111853.571882  137076.683206  201620.892054  106246.041384
#
# 광역시도          울산광역시            강원도           전라남도   세종특별자치시
# max   327270.000000  313851.000000  263166.000000  191233.0
# mean  221117.000000   79413.222222   77298.318182  191233.0
# std    64163.286582   87316.383238   74413.253230       0.0

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

# %%
# 폰트이름과 폰트 파일 정보 출력: list comprehension
[(font.name, font.fname) for font in fm.fontManager.ttflist if 'Ma' in font.name]
# Out:
# [('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Matura MT Script Capitals', 'C:\\Windows\\Fonts\\MATURASC.TTF'),
#  ('Malgun Gothic',
#   'C:\\Users\\junkyu-laptop\\AppData\\Local\\Microsoft\\Windows\\Fonts\\malgun.ttf'),
#  ('Magic R', 'C:\\Windows\\Fonts\\HMKMMAG.TTF'),
#  ('Marlett', 'C:\\Windows\\Fonts\\marlett.ttf'),
#  ('Maiandra GD', 'C:\\Windows\\Fonts\\MAIAN.TTF'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Malgun Gothic',
#   'C:\\Users\\junkyu-laptop\\AppData\\Local\\Microsoft\\Windows\\Fonts\\malgunsl.ttf'),
#  ('Magneto', 'C:\\Windows\\Fonts\\MAGNETOB.TTF'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf')]

# %%
#한글폰트 설정
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
# font의 파일정보로 font name을 알아내기
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
# matplotlib의 rc(run command) 함수를 사용해서 폰트이름 설정
matplotlib.rc('font', family=font_prop)
# Out:
# Malgun Gothic

# %%
seoul_df.head()
# Out:
#      Unnamed: 0     인구수 shortName  x  y    면적   광역시도 행정구역
# 124         124  526157      서울강남  6  7  39.5  서울특별시  강남구
# 125         125  432028      서울강동  8  5  24.6  서울특별시  강동구
# 126         126  310292      서울강북  5  2  23.6  서울특별시  강북구
# 127         127  554709      서울강서  4  4  41.4  서울특별시  강서구
# 128         128  484478      서울관악  5  6  29.6  서울특별시  관악구

# %%
kangwon_df = data.loc[data['광역시도'] == '강원도']

kangwon_df
# Out:
#     Unnamed: 0     인구수 shortName   x  y       면적 광역시도 행정구역
# 0            0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1            1   25589    고성(강원)   9  0   664.19  강원도  고성군
# 2            2   86747        동해  11  5   180.01  강원도  동해시
# 3            3   63986        삼척  11  8  1185.80  강원도  삼척시
# 4            4   76733        속초   9  1   105.25  강원도  속초시
# 5            5   20809        양구   8  0   700.80  강원도  양구군
# 6            6   24551        양양  10  2   628.68  강원도  양양군
# 7            7   34966        영월  10  8  1127.36  강원도  영월군
# 8            8  313851        원주  10  7   867.30  강원도  원주시
# 9            9   29260        인제   9  2  1646.08  강원도  인제군
# 10          10   34242        정선  11  6  1220.67  강원도  정선군
# 11          11   43189        철원   6  0   899.82  강원도  철원군
# 12          12  264144        춘천  10  3  1116.35  강원도  춘천시
# 13          13   44175        태백  11  7   303.57  강원도  태백시
# 14          14   38439        평창  10  6  1463.65  강원도  평창군
# 15          15   62957        홍천  10  4  1817.94  강원도  홍천군
# 16          16   23612        화천   7  0   909.45  강원도  화천군
# 17          17   39668        횡성  10  5   997.82  강원도  횡성군

# %%
figure,(axes1,axes2) = plt.subplots(nrows=2, ncols=1)
figure.set_size_inches(18,12)
print(figure)
print(axes1)
print(axes2)
# sns.barplot(x='행정구역', y='인구수', data=seoul_df.sort_values(by='인구수', ascending=False), ax=axes1)
# sns.barplot(x='행정구역', y='면적', data=seoul_df.sort_values(by='면적', ascending=False), ax=axes2)
# Out:
# Figure(1296x864)
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
def print_barplot(sido_name):
    sido_df = data.loc[data['광역시도'] == sido_name]
    figure,(axes1,axes2) = plt.subplots(nrows=2, ncols=1)
    figure.set_size_inches(18,12)
    a = sns.barplot(x='행정구역', y='인구수', data=sido_df.sort_values(by='인구수', ascending=False), ax=axes1)
    a.set_title(f'{sido_name} 행정구역별 인구수')
    b = sns.barplot(x='행정구역', y='면적', data=sido_df.sort_values(by='면적', ascending=False), ax=axes2)
    b.set_title(f'{sido_name} 행정구역별 면적')

print_barplot('경기도')

# %%
figure, axes1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)
sns.barplot(x='광역시도', y='인구수', data=data, ax=axes1)
# Out:
# <AxesSubplot:xlabel='광역시도', ylabel='인구수'>

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)
sns.barplot(data=seoul_df, x="행정구역", y="인구수", ax=ax1)
ax1.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
ax1.set(ylabel='인구수')
for item in ax1.get_xticklabels():
    item.set_rotation(90)
for i, v in enumerate(seoul_df["인구수"].iteritems()):
    ax1.text(i ,v[1], "{:,}".format(v[1]), color='m', va ='bottom', rotation=45)
plt.tight_layout()

# %%
figure, axes1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)
sns.barplot(x='행정구역', y='인구수', data=kangwon_df.sort_values(by='인구수', ascending=False), ax=axes1)
# Out:
# <AxesSubplot:xlabel='행정구역', ylabel='인구수'>

# %%
kangwon_df
# Out:
#     Unnamed: 0     인구수 shortName   x  y       면적 광역시도 행정구역
# 0            0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1            1   25589    고성(강원)   9  0   664.19  강원도  고성군
# 2            2   86747        동해  11  5   180.01  강원도  동해시
# 3            3   63986        삼척  11  8  1185.80  강원도  삼척시
# 4            4   76733        속초   9  1   105.25  강원도  속초시
# 5            5   20809        양구   8  0   700.80  강원도  양구군
# 6            6   24551        양양  10  2   628.68  강원도  양양군
# 7            7   34966        영월  10  8  1127.36  강원도  영월군
# 8            8  313851        원주  10  7   867.30  강원도  원주시
# 9            9   29260        인제   9  2  1646.08  강원도  인제군
# 10          10   34242        정선  11  6  1220.67  강원도  정선군
# 11          11   43189        철원   6  0   899.82  강원도  철원군
# 12          12  264144        춘천  10  3  1116.35  강원도  춘천시
# 13          13   44175        태백  11  7   303.57  강원도  태백시
# 14          14   38439        평창  10  6  1463.65  강원도  평창군
# 15          15   62957        홍천  10  4  1817.94  강원도  홍천군
# 16          16   23612        화천   7  0   909.45  강원도  화천군
# 17          17   39668        횡성  10  5   997.82  강원도  횡성군
